# %%
from pathlib import Path
from typing import Union, List
from phenopackets.schema.v2 import Phenopacket
import phenopackets
from phenopacket_mapper.mapping.mapper import PhenopacketMapper, PhenopacketElement
from rarelink.preprocessing.preprocess_redcap_for_phenopackets import preprocess_redcap_for_phenopackets
from rarelink.rarelink_cdm import RARELINK_CDM_V2_0_0
from rarelink.preprocessing import preprocess_redcap_for_phenopackets
from rarelink.rarelink_cdm.rarelink_cdm import load_rarelink_data
from rarelink.rarelink_cdm import rarelink_cdm_phenopackets_mapping
from rarelink.pipelines.redcap_phenopacket_pipeline import rarelink_cdm_phenopacket_pipeline

# %%
rarelink_cdm_phenopacket_pipeline('/Users/adam/Documents/GIT/RareLink/res/RareLink2.0_Test_Data_no_family.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 rarelink_cdm_phenopacket_pipeline('/Users/adam/Documents/GIT/RareLink/res/RareLink2.0_Test_Data_no_family.csv')
#
# File ~/Documents/git/RareLink/src/rarelink/pipelines/redcap_phenopacket_pipeline/phenopacket_pipeline.py:18, in rarelink_cdm_phenopacket_pipeline(path)
#      15 def rarelink_cdm_phenopacket_pipeline(path: Union[str, Path]) -> List[Phenopacket]:
#      16     # 1. load data
#      17     data_model = RARELINK_CDM_V2_0_0
# ---> 18     data_set = load_rarelink_data(path)
#      19     print("idsd of the fields in the data model: \n",
#      20           data_model.data_model.get_field_ids())
#      21     # 2. Preprocessing
#
# File ~/Documents/git/RareLink/src/rarelink/rarelink_cdm/rarelink_cdm.py:453, in load_rarelink_data(path, data_model)
#     452 def load_rarelink_data(path: Union[str, Path], data_model: DataModel = RARELINK_CDM_V2_0_0):
# --> 453     return data_model.load_data(
#     454         path,
#     455         pseudonym_column="snomed_422549004",
#     456         date_of_admission_column="snomed_399423000",
#     457         date_of_birth_column="snomed_184099003",
#     458         sex_at_birth_column="snomed_281053000",
#     459         karyotypic_sex_column="snomed_1296886006",
#     460         gender_identity_column="snomed_263495000",
#     461         country_of_birth_column="snomed_370159000",
#     462         vital_status_column="snomed_278844005",
#     463         time_of_death_column="snomed_398299004",
#     464         cause_of_death_column="snomed_184305005",
#     465         age_category_column="snomed_105727008",
#     466         length_of_gestation_at_birth_column="snomed_412726003",
#     467         undiagnosed_rd_case_column="snomed_723663001",
#     468         encounter_start_column="hl7fhir_enc_period_start",
#     469         encounter_end_column="hl7fhir_enc_period_end",
#     470         encounter_status_column="snomed_305058001",
#     471         encounter_class_column="hl7fhir_encounter_class",
#     472         disease_mondo_column="snomed_64572001_mondo",
#     473         disease_ordo_column="snomed_64572001_ordo",
#     474         disease_icd10cm_column="snomed_64572001_icd10cm",
#     475         disease_icd11_column="snomed_64572001_icd11",
#     476         disease_omim_p_column="snomed_64572001_omim_p",
#     477         verification_status_column="loinc_99498_8",
#     478         age_at_onset_column="snomed_424850005",
#     479         date_of_onset_column="snomed_298059007",
#     480         age_at_diagnosis_column="snomed_423493009",
#     481         date_of_diagnosis_column="snomed_432213005",
#     482         body_site_column="snomed_363698007",
#     483         clinical_status_column="snomed_263493007",
#     484         severity_column="snomed_246112005",
#     485         genomic_diagnosis_mondo_column="snomed_106221001_mondo",
#     486         genomic_diagnosis_omim_p="snomed_106221001_omim_p",
#     487         progress_status_of_interpretation_column="ga4gh_progress_status",
#     488         interpretation_status_column="ga4gh_interp_status",
#     489         structural_variant_analysis_method_column="loinc_81304_8",
#     490         structural_variant_analysis_method_other_column="loinc_81304_8_other",
#     491         reference_genome_column="loinc_62374_4",
#     492         genetic_mutation_string_column="loinc_lp7824_8",
#     493         genomic_dna_change_column="loinc_81290_9",
#     494         sequence_dna_change_column="loinc_48004_6",
#     495         amino_acid_change_column="loinc_48005_3",
#     496         gene_column="loinc_48018_6",
#     497         gene_label_column="loinc_48018_6_label",
#     498         zygosity_column="loinc_53034_5",
#     499         zygosity_other_column="loinc_53034_5_other",
#     500         genomic_source_class_column="loinc_48002_0",
#     501         dna_change_type_column="loinc_48019_4",
#     502         dna_change_type_other_column="loinc_48019_4_other",
#     503         clinical_significance_acmg_column="loinc_53037_8",
#     504         therapeutic_actionability_column="ga4gh_therap_action",
#     505         clinical_annotation_level_of_evidence_column="loinc_93044_6",
#     506         phenotypic_feature_column="snomed_8116006",
#     507         determination_date_column="snomed_8116006_date",
#     508         status_column="ga4gh_pheno_excluded",
#     509         modifier_hpo_1_column="ga4gh_pheno_mod_hp1",
#     510         modifier_hpo_2_column="ga4gh_pheno_mod_hp2",
#     511         modifier_hpo_3_column="ga4gh_pheno_mod_hp3",
#     512         modifier_ncbitaxon_1_column="ga4gh_pheno_mod_ncbitax1",
#     513         modifier_ncbitaxon_2_column="ga4gh_pheno_mod_ncbitax2",
#     514         modifier_ncbitaxon_3_column="ga4gh_pheno_mod_ncbitax3",
#     515         modifier_snomed_ct_1_column="ga4gh_pheno_mod_snomed1",
#     516         modifier_snomed_ct_2_column="ga4gh_pheno_mod_snomed2",
#     517         modifier_snomed_ct_3_column="ga4gh_pheno_mod_snomed3",
#     518         family_member_pseudonym_column="family_history_pseudonym",
#     519         propositus_a_column="snomed_64245008",
#     520         relationship_of_the_individual_to_the_index_case_propositus_a_column=
#     521                             "snomed_408732007",
#     522         consanguinity_column="snomed_842009",
#     523         family_member_relationship_column="snomed_444018008",
#     524         family_member_record_status_column="hl7fhir_fmh_status",
#     525         family_member_sex_column="loinc_54123_5",
#     526         family_member_age_column="loinc_54141_7",
#     527         family_member_date_of_birth_column="loinc_54124_3",
#     528         family_member_deceased_column="snomed_740604001",
#     529         family_member_cause_of_death_column="loinc_54112_8",
#     530         family_member_deceased_age_column="loinc_92662_6",
#     531         family_member_disease_column="loinc_75315_2",
#     532         consent_status_column="snomed_309370004",
#     533         consent_date_column="hl7fhir_consent_datetime",
#     534         health_policy_monitoring_column="snomed_386318002",
#     535         agreement_to_be_contacted_for_research_purposes="rarelink_consent_contact",
#     536         consent_to_the_reuse_of_data_column="rarelink_consent_data",
#     537         biological_sample_column="snomed_123038009",
#     538         link_to_a_biobankcolumn="rarelink_biobank_link",
#     539         classification_of_functioning_disability_column="rarelink_icf_score"
#     540     )
#
# File ~/Documents/git/RareLink/submodules/phenopacket_mapper/src/phenopacket_mapper/data_standards/data_model.py:226, in DataModel.load_data(self, path, compliance, **kwargs)
#     224 column_param = f"{f.id}_column"
#     225 if column_param not in kwargs:
# --> 226     raise TypeError(f"load_data() missing 1 required argument: '{column_param}'")
#     227 else:
#     228     column_names[f.id] = kwargs[column_param]
#
# TypeError: load_data() missing 1 required argument: 'agreement_to_be_contacted_for_research_purposes_column'
